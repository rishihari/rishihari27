# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e71afca-e3c0-4d81-8241-8367b8f7ec2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e71afca-e3c0-4d81-8241-8367b8f7ec2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['House Price India.csv']))
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %% [markdown]
# UNIVARIANT

# %%
df.loc[df['Price']==2300000]
# Out:
#               id   Date  number of bedrooms  number of bathrooms  living area  \
# 3495  6762810155  42545                   4                 3.25         4250
# 3948  6762810156  42551                   4                 4.75         3970
# 6335  6762810157  42586                   4                 2.50         3280
# 6591  6762810158  42589                   7                 4.75         5310
# 7221  6762810159  42600                   4                 3.25         4110
#
#       lot area  number of floors  waterfront present  number of views  \
# 3495      8570               2.0                   0                0
# 3948      9778               2.0                   0                2
# 6335      7100               2.0                   0                4
# 6591      8816               2.0                   0                0
# 7221     15929               2.0                   1                4
#
# ...

# %%
df.loc[df['number of floors']==2.0]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 3      6762812605  42491                   4                 2.50
# 6      6762813157  42491                   5                 3.25
# 7      6762813599  42491                   3                 1.75
# 10     6762814787  42491                   5                 2.50
# ...           ...    ...                 ...                  ...
# 14597  6762820484  42734                   3                 2.50
# 14599  6762821149  42734                   3                 2.50
# 14601  6762821927  42734                   3                 2.25
# 14606  6762825822  42734                   3                 2.50
# 14607  6762825951  42734                   3                 2.50
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.loc[df['Date']==42734]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14575  6762810958  42734                   4                 2.50
# 14576  6762811865  42734                   3                 2.50
# 14577  6762812040  42734                   3                 2.50
# 14578  6762812266  42734                   3                 1.00
# 14579  6762812706  42734                   3                 1.50
# 14580  6762812743  42734                   4                 2.50
# 14581  6762813082  42734                   3                 3.25
# 14582  6762813562  42734                   3                 3.25
# 14583  6762814575  42734                   3                 2.00
# 14584  6762814596  42734                   4                 2.75
# 14585  6762815000  42734                   4                 2.50
# 14586  6762816042  42734                   5                 2.75
# 14587  6762816137  42734                   6                 3.00
# ...

# %%
df.loc[df['number of bedrooms']==3]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 4      6762812919  42491                   3                 2.00
# 5      6762813105  42491                   3                 2.50
# 7      6762813599  42491                   3                 1.75
# 8      6762813600  42491                   3                 2.50
# 14     6762815737  42491                   3                 2.25
# ...           ...    ...                 ...                  ...
# 14612  6762828856  42734                   3                 1.00
# 14613  6762829600  42734                   3                 1.00
# 14614  6762829669  42734                   3                 1.75
# 14616  6762830339  42734                   3                 2.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 4             2710      4500               1.5                   0
# ...

# %%
df.loc[df['number of bathrooms']==3]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 48     6762824201  42491                   4                  3.0
# 58     6762827693  42491                   3                  3.0
# 84     6762812331  42494                   4                  3.0
# 86     6762812659  42494                   4                  3.0
# 118    6762818230  42494                   2                  3.0
# ...           ...    ...                 ...                  ...
# 14476  6762813176  42732                   3                  3.0
# 14481  6762815079  42732                  10                  3.0
# 14544  6762815686  42733                   6                  3.0
# 14549  6762818055  42733                   4                  3.0
# 14587  6762816137  42734                   6                  3.0
#
#        living area  lot area  number of floors  waterfront present  \
# 48            3110      7231               2.0                   0
# ...

# %%
df.loc[df['condition of the house']==3]
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 6      6762813157  42491                   5                 3.25
# 10     6762814787  42491                   5                 2.50
# 11     6762815225  42491                   4                 2.00
# ...           ...    ...                 ...                  ...
# 14609  6762826741  42734                   3                 2.00
# 14611  6762828783  42734                   3                 1.75
# 14614  6762829669  42734                   3                 1.75
# 14617  6762830618  42734                   2                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 2             2910      9480               1.5                   0
# ...

# %%
df.loc[df['Built Year']==2002]

# %% [markdown]
# UNIVARIANT ANALYSIS

# %%
df_price=df.loc[df['Price']==2300000]
df_floors=df.loc[df['number of floors']==2.0]

plt.plot(df_price['lot area'],np.zeros_like(df_price['lot area']))
plt.plot(df_floors['living area'],np.zeros_like(df_floors['living area']))
plt.show()

# %% [markdown]
# BIVARIANT ANALYSIS

# %%
sns.FacetGrid(df,hue='number of bedrooms').map(plt.scatter,'living area','lot area').add_legend();
plt.show()

# %% [markdown]
# MULTIVIBIRANT ANALYSIS

# %%
sns.pairplot(df,hue='living area',size=8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-be5eb3f55553> in <cell line: 1>()
# ----> 1 sns.pairplot(df,hue='living area',size=8)
#
# NameError: name 'sns' is not defined
